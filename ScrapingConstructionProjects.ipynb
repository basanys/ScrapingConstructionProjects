# %%
import twint

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
#c.Limit = 100
c.Since = '2020-01-01'
c.Search = "africa dam projects"
c.Pandas = True
c.Filter_retweets = True

# Run
twint.run.Search(c)

#Save to pandas
Tweets_df = twint.storage.panda.Tweets_df
# Out:
# 1390252365803147268 2021-05-06 12:29:28 +0200 <GWPSAF> Christo Dudenski from @DWS_RSA provided a description of the Noordoewer Vioolsdrift Dam (NVD) Project - this is a joint project between the governments of Namibia and South Africa and is currently in the planning stage.   Read more about this project below! #PIDAPAP2 #water  https://t.co/aOXMDmtVkk
# 1389982048312561667 2021-05-05 18:35:19 +0200 <CNNAfrica> CNN's @ZainAsher speaks to Sudanese Prime Minister Abdalla Hamdok about concerns over the Nile Dam project and Sudan's relations with Ethiopia  https://t.co/Oj5vrkMmSZ
# 1389624431790657539 2021-05-04 18:54:17 +0200 <mesfinb3> @AmbShinn Good for China and the African nations. When did America ever built anything useful for Africa? Ethiopia's  effort to get international financing  was blocked for over 3/4 of a century by the likes of America and now the self financed dam project is getting sabotaged by the same.
# ...

# %%
Custom_df = Tweets_df[['date', 'tweet', 'link', 'urls']]

# %%
#Custom_df.to_excel('/Users/basan/PythonExcel.xlsx')
